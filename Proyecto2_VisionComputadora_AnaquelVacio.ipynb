# %% [markdown]
# Isabel Portuguez Calderón
#
# Mario Quirós Luna
#
# Proyecto 2 - Expertos
#
# Visión por computadora de anaqueles vacios de supermercado

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -r requirements.txt

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-186-g0acc5cf Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %%
# !unzip -qn /content/Inventario -d ../

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data inventario_data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights ../yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.30 --source ../1.jpg
